# %%
import numpy as np
import netCDF4
import matplotlib.pyplot as plot

# %matplotlib inline

# %%
fh = netCDF4.Dataset("../output.nc")
d = fh.variables['data'][:][:,:,0]

plot.figure(figsize=(10,8))
#cmap = plot.get_cmap('jet', len(np.unique(d))-1)
plot.pcolormesh(d, )#cmap=cmap)
plot.gca().set_aspect(1)
#plot.colorbar(ticks=np.unique(d))
plot.colorbar()
fh.close()

# %%
fh = netCDF4.Dataset("../mask_field.nc")
d = fh.variables['fieldext'][:][:,:,0]
m = fh.variables['maskext'][:][:,:,0]

print np.unique(d)

plot.figure(figsize=(10,8))
plot.pcolormesh(np.ma.masked_array(d, mask=np.logical_not(m)))

plot.gca().set_aspect(1)
plot.colorbar()
# Out:
# [    0 32767]

# %%
d_m = np.ma.masked_array(d, mask=np.logical_not(m))

print d_m.max()
# Out:
# 32765

# %%
plot.figure(figsize=(10,8))
plot.pcolormesh(d_m == d_m.max())
plot.gca().set_aspect(1)
plot.colorbar()
